# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import cv2
import cv
import numpy as np
import pylab as pl
import scipy.ndimage
import itertools
import scipy.optimize

# %%
class Undistortor(object):
    def __init__(self, image):
        #self.cam_mat, self.coefs = self._find_cam_matrix(image)
        self.distance_fun(image)
    #def distance_fun(self,image,f = 5000, k = -3):
        
    def distance_fun(self,image,f = 5000, k = -3):
        erosion_size=9
        kern_size = 2*erosion_size + 1
        elem = cv2.getStructuringElement( cv2.MORPH_ELLIPSE, (kern_size, kern_size),(erosion_size, erosion_size))
        grey = cv2.medianBlur(image,3)
        morph = cv2.dilate(grey, elem)
        morph = cv2.erode(morph, elem)
        morph = cv2.subtract(morph, grey)
        p = np.percentile(morph,90)
        
        _,morph = cv2.threshold(morph,p,255,cv.CV_THRESH_BINARY)
        cam_mat, coefs = self._find_cam_matrix(morph, f, k)
        tmp = cv2.undistort(morph, cam_mat, coefs)
        lines = cv2.HoughLinesP(tmp, rho=1, theta=np.pi/180.0, threshold=1, minLineLength=image.shape[0]/1.5)
        #pl.imshow(tmp)
        
        if lines is None:
            return np.Inf
        
        else:
            return 1/float(lines.shape[1])
        
    def _find_cam_matrix(self, image,f,k):
        camera_matrix = np.zeros((3,3),'float32')
        camera_matrix[0,0]= f
        camera_matrix[1,1]= f
        camera_matrix[2,2]=1.0
        camera_matrix[0,2]=grid_grey.shape[1]/2.0
        camera_matrix[1,2]=grid_grey.shape[0]/2.0
        dist_coefs = np.array([k,k,0,0],'float32')
        return camera_matrix, dist_coefs

    
    def undistort(self, image):
        cam_mat=self.cam_mat
        coefs=self.coefs
        return cv2.undistort(image, cam_mat, coefs)

# %%
grid_img = cv2.imread("grid_test.jpg")
grid_grey = cv2.cvtColor(grid_img, cv.CV_BGR2GRAY)
ud = Undistortor(grid_grey)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-add2245e499a> in <module>()
#       1 grid_img = cv2.imread("grid_test.jpg")
#       2 grid_grey = cv2.cvtColor(grid_img, cv.CV_BGR2GRAY)
# ----> 3 ud = Undistortor(grid_grey)
#
# <ipython-input-134-97b1b203b1a6> in __init__(self, image)
#       2     def __init__(self, image):
#       3         #self.cam_mat, self.coefs = self._find_cam_matrix(image)
# ----> 4         self.distance_fun(image)
#       5     #def distance_fun(self,image,f = 5000, k = -3):
#       6
#
# <ipython-input-134-97b1b203b1a6> in distance_fun(self, image, f, k)
#      20         lines = cv2.HoughLinesP(tmp, rho=1, theta=np.pi/180.0, threshold=1, minLineLength=image.shape[0]/1.5)
#      21         pl.imshow(tmp)
# ---> 22         print lines.shape
#      23
#      24     def _find_cam_matrix(self, image,f,k):
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
pl.imshow(ud.undistort(grid_img))
